# %%
import spacy

# %%
nlp=spacy.load('en_core_web_sm')
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
train=[
    ("Show me a picture where man performing mayura on left hand and chatura on right hand with hasya rasa", {"entities": [(24, 27, 'GENDER'), (39, 45, 'MUDRA'), (63, 70, 'MUDRA'), (90, 95, 'FAC')]}),
("Get an image of she performing samputa with veera rasa", {"entities": [(16, 19, 'GENDER'), (31, 38, 'MUDRA'), (44, 49, 'FAC')]}),
("Fetch me a picture where mister performing anjali with hasya rasa", {"entities": [(25, 31, 'GENDER'), (43, 49, 'MUDRA'), (55, 60, 'FAC')]}),
("Show a pic which lady performing hamsohasso on left hand and alapadma on right hand with advuta rasa", {"entities": [(17, 21, 'GENDER'), (33, 43, 'MUDRA'), (61, 69, 'MUDRA'), (89, 95, 'FAC')]}),
("Retrieve in female performing pasha with advuta rasa", {"entities": [(12, 18, 'GENDER'), (30, 35, 'MUDRA'), (41, 47, 'FAC')]}),
("Retrieve an instance which female performing samdamsa on left hand and shukatundaka on right hand with hasya rasa", {"entities": [(27, 33, 'GENDER'), (45, 53, 'MUDRA'), (71, 83, 'MUDRA'), (103, 108, 'FAC')]}),
("Retrieve an image of he performing chatura on left hand and bhramara on right hand with rudra rasa", {"entities": [(21, 23, 'GENDER'), (35, 42, 'MUDRA'), (60, 68, 'MUDRA'), (88, 93, 'FAC')]}),
("Get which miss performing bhramara on left hand and tamrachura on right hand with karuna rasa", {"entities": [(10, 14, 'GENDER'), (26, 34, 'MUDRA'), (52, 62, 'MUDRA'), (82, 88, 'FAC')]}),
("Show a pic which male performing ardhachandra on left hand and kangula on right hand with karuna rasa", {"entities": [(17, 21, 'GENDER'), (33, 45, 'MUDRA'), (63, 70, 'MUDRA'), (90, 96, 'FAC')]}),
("Get me an image of female performing kapittha on left hand and shukatundaka on right hand with advuta rasa", {"entities": [(19, 25, 'GENDER'), (37, 45, 'MUDRA'), (63, 75, 'MUDRA'), (95, 101, 'FAC')]}),
("Retrieve an instance where girl performing arala on left hand and mrigashirsha on right hand with hasya rasa", {"entities": [(27, 31, 'GENDER'), (43, 48, 'MUDRA'), (66, 78, 'MUDRA'), (98, 103, 'FAC')]}),
("Retrieve an image in boy performing mushti on left hand and arala on right hand with hasya rasa", {"entities": [(21, 24, 'GENDER'), (36, 42, 'MUDRA'), (60, 65, 'MUDRA'), (85, 90, 'FAC')]}),
("Show me a picture of mister performing samdamsa on left hand and kapittha on right hand with hasya rasa", {"entities": [(21, 27, 'GENDER'), (39, 47, 'MUDRA'), (65, 73, 'MUDRA'), (93, 98, 'FAC')]}),
("Fetch in lady performing swastika with veera rasa", {"entities": [(9, 13, 'GENDER'), (25, 33, 'MUDRA'), (39, 44, 'FAC')]}),
("Retrieve an instance in mister performing kartari on left hand and tamrachura on right hand with hasya rasa", {"entities": [(24, 30, 'GENDER'), (42, 49, 'MUDRA'), (67, 77, 'MUDRA'), (97, 102, 'FAC')]}),
("Show a pic of man performing baraha with rudra rasa", {"entities": [(14, 17, 'GENDER'), (29, 35, 'MUDRA'), (41, 46, 'FAC')]}),
("Show me which mister performing chatura on left hand and kapittha on right hand with shringer rasa", {"entities": [(14, 20, 'GENDER'), (32, 39, 'MUDRA'), (57, 65, 'MUDRA'), (85, 93, 'FAC')]}),
("Fetch in man performing swastika with rudra rasa", {"entities": [(9, 12, 'GENDER'), (24, 32, 'MUDRA'), (38, 43, 'FAC')]}),
("Get me an image in she performing ardhachandra on left hand and trishula on right hand with rudra rasa", {"entities": [(19, 22, 'GENDER'), (34, 46, 'MUDRA'), (64, 72, 'MUDRA'), (92, 97, 'FAC')]}),
("Get me an image where woman performing singhamukha on left hand and ardhachandra on right hand with veera rasa", {"entities": [(22, 27, 'GENDER'), (39, 50, 'MUDRA'), (68, 80, 'MUDRA'), (100, 105, 'FAC')]}),
("Show me a picture where male performing ardhachandra on left hand and mukula on right hand with shringer rasa", {"entities": [(24, 28, 'GENDER'), (40, 52, 'MUDRA'), (70, 76, 'MUDRA'), (96, 104, 'FAC')]}),
("Get me an image in female performing suchi on left hand and shukatundaka on right hand with bhaya rasa", {"entities": [(19, 25, 'GENDER'), (37, 42, 'MUDRA'), (60, 72, 'MUDRA'), (92, 97, 'FAC')]}),
("Get an image where female performing mushti on left hand and ardhachandra on right hand with karuna rasa", {"entities": [(19, 25, 'GENDER'), (37, 43, 'MUDRA'), (61, 73, 'MUDRA'), (93, 99, 'FAC')]}),
("Get me an image which boy performing karkata with advuta rasa", {"entities": [(22, 25, 'GENDER'), (37, 44, 'MUDRA'), (50, 56, 'FAC')]}),
("Retrieve which boy performing singhamukha on left hand and mrigashirsha on right hand with advuta rasa", {"entities": [(15, 18, 'GENDER'), (30, 41, 'MUDRA'), (59, 71, 'MUDRA'), (91, 97, 'FAC')]}),
("Fetch of miss performing anjali with rudra rasa", {"entities": [(9, 13, 'GENDER'), (25, 31, 'MUDRA'), (37, 42, 'FAC')]}),
("Show which man performing shikhara on left hand and arala on right hand with bhaya rasa", {"entities": [(11, 14, 'GENDER'), (26, 34, 'MUDRA'), (52, 57, 'MUDRA'), (77, 82, 'FAC')]}),
("Retrieve of he performing singhamukha on left hand and hamsapakshaka on right hand with rudra rasa", {"entities": [(12, 14, 'GENDER'), (26, 37, 'MUDRA'), (55, 68, 'MUDRA'), (88, 93, 'FAC')]}),
("Fetch in woman performing utsang with veera rasa", {"entities": [(9, 14, 'GENDER'), (26, 32, 'MUDRA'), (38, 43, 'FAC')]}),
("Fetch me an image of she performing trishula on left hand and sharpashirastatha on right hand with shanta rasa", {"entities": [(21, 24, 'GENDER'), (36, 44, 'MUDRA'), (62, 79, 'MUDRA'), (99, 105, 'FAC')]}),
("Get me an image of man performing kapittha on left hand and chatura on right hand with karuna rasa", {"entities": [(19, 22, 'GENDER'), (34, 42, 'MUDRA'), (60, 67, 'MUDRA'), (87, 93, 'FAC')]}),
("Show me which girl performing kangula on left hand and ardhapatake on right hand with hasya rasa", {"entities": [(14, 18, 'GENDER'), (30, 37, 'MUDRA'), (55, 66, 'MUDRA'), (86, 91, 'FAC')]}),
("Get me of mister performing katakavardhana with bhaya rasa", {"entities": [(10, 16, 'GENDER'), (28, 42, 'MUDRA'), (48, 53, 'FAC')]}),
("Show a pic where woman performing sakata with shringer rasa", {"entities": [(17, 22, 'GENDER'), (34, 40, 'MUDRA'), (46, 54, 'FAC')]}),
("Fetch me an image where boy performing mayura on left hand and hamsapakshaka on right hand with karuna rasa", {"entities": [(24, 27, 'GENDER'), (39, 45, 'MUDRA'), (63, 76, 'MUDRA'), (96, 102, 'FAC')]}),
("Fetch me a picture in female performing mayura on left hand and kartari on right hand with hasya rasa", {"entities": [(22, 28, 'GENDER'), (40, 46, 'MUDRA'), (64, 71, 'MUDRA'), (91, 96, 'FAC')]}),
("Show in male performing mushti on left hand and sharpashirastatha on right hand with karuna rasa", {"entities": [(8, 12, 'GENDER'), (24, 30, 'MUDRA'), (48, 65, 'MUDRA'), (85, 91, 'FAC')]}),
("Fetch me a picture where girl performing chandrakala on left hand and alapadma on right hand with hasya rasa", {"entities": [(25, 29, 'GENDER'), (41, 52, 'MUDRA'), (70, 78, 'MUDRA'), (98, 103, 'FAC')]}),
("Show a pic in male performing arala on left hand and singhamukha on right hand with bibhatsya rasa", {"entities": [(14, 18, 'GENDER'), (30, 35, 'MUDRA'), (53, 64, 'MUDRA'), (84, 93, 'FAC')]}),
("Fetch in lady performing nagabandha with bhaya rasa", {"entities": [(9, 13, 'GENDER'), (25, 35, 'MUDRA'), (41, 46, 'FAC')]}),
("Get me an image in lady performing katakamukha on left hand and chatura on right hand with bibhatsya rasa", {"entities": [(19, 23, 'GENDER'), (35, 46, 'MUDRA'), (64, 71, 'MUDRA'), (91, 100, 'FAC')]}),
("Show me in she performing tamrachura on left hand and alapadma on right hand with shanta rasa", {"entities": [(11, 14, 'GENDER'), (26, 36, 'MUDRA'), (54, 62, 'MUDRA'), (82, 88, 'FAC')]}),
("Retrieve an image of miss performing chatura on left hand and singhamukha on right hand with shanta rasa", {"entities": [(21, 25, 'GENDER'), (37, 44, 'MUDRA'), (62, 73, 'MUDRA'), (93, 99, 'FAC')]}),
("Retrieve where mister performing chatura on left hand and mayura on right hand with bibhatsya rasa", {"entities": [(15, 21, 'GENDER'), (33, 40, 'MUDRA'), (58, 64, 'MUDRA'), (84, 93, 'FAC')]}),
("Fetch me an image of miss performing bhramara on left hand and padmakosha on right hand with shanta rasa", {"entities": [(21, 25, 'GENDER'), (37, 45, 'MUDRA'), (63, 73, 'MUDRA'), (93, 99, 'FAC')]}),
("Retrieve an image which miss performing matsya with karuna rasa", {"entities": [(24, 28, 'GENDER'), (40, 46, 'MUDRA'), (52, 58, 'FAC')]}),
("Show in male performing hamsohasso on left hand and padmakosha on right hand with bhaya rasa", {"entities": [(8, 12, 'GENDER'), (24, 34, 'MUDRA'), (52, 62, 'MUDRA'), (82, 87, 'FAC')]}),
("Show me where miss performing dolahasta with hasya rasa", {"entities": [(14, 18, 'GENDER'), (30, 39, 'MUDRA'), (45, 50, 'FAC')]}),
("Show me a picture which male performing hamsapakshaka on left hand and pataka on right hand with veera rasa", {"entities": [(24, 28, 'GENDER'), (40, 53, 'MUDRA'), (71, 77, 'MUDRA'), (97, 102, 'FAC')]}),
("Retrieve an image in lady performing alapadma on left hand and singhamukha on right hand with advuta rasa", {"entities": [(21, 25, 'GENDER'), (37, 45, 'MUDRA'), (63, 74, 'MUDRA'), (94, 100, 'FAC')]}),
]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in train:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
disable_pipes=[pipe for pipe in nlp.pipe_names if pipe !='ner']

# %%
import random
from spacy.util import minibatch, compounding
from spacy.training.example import Example
from pathlib import Path

with nlp.disable_pipes(*disable_pipes):
    optimizer=nlp.resume_training()

    for iteration in range(100):
        random.shuffle(train)
        losses={}
        
        batches=minibatch(train,size=compounding(1.0,4.0,1.001))
        for batch in batches:
            l=[]
            for text,entity in batch:
                doc = nlp.make_doc(text)
#                 tags=spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), [entity['entities'][0]])
#                 print(tags)
                example = Example.from_dict(doc, entity)
                l.append(example)
#             print(batch)
#             text,annotation=zip(*batch)
#             print(text)
#             doc = nlp.make_doc(text)
#             example = Example.from_dict(doc, annotations)
            nlp.update(
                l,
                drop=0.5,
                losses=losses,
                sgd=optimizer
            )
            print("losses",losses)
# Out:
# losses {'ner': 8.738947842200673}
# losses {'ner': 17.926178198096437}
# losses {'ner': 23.91964158202244}
# losses {'ner': 32.64346523824318}
# losses {'ner': 39.60293077320865}
# losses {'ner': 46.91673713798002}
# losses {'ner': 54.62154669560325}
# losses {'ner': 59.83168737840381}
# losses {'ner': 67.7239493860557}
# losses {'ner': 74.68428312256358}
# losses {'ner': 84.87786401398765}
# losses {'ner': 92.84621871000448}
# losses {'ner': 98.98244822656446}
# losses {'ner': 107.05299402246376}
# losses {'ner': 110.61371996563824}
# losses {'ner': 115.28715802783111}
# losses {'ner': 124.61641825230029}
# losses {'ner': 132.65471132684027}
# losses {'ner': 143.75189957591058}
# losses {'ner': 150.93265336089237}
# losses {'ner': 157.04475533810322}
# losses {'ner': 162.71278492782724}
# losses {'ner': 169.8470791604573}
# losses {'ner': 176.70969457306413}
# losses {'ner': 182.43379175238945}
# losses {'ner': 186.74928004237293}
# losses {'ner': 189.9254347591864}
# ...

# %%
from spacy import displacy
q_list=[
    "Retrieve an instance which boy performing nagabandha",
    "Show a pic in mister performing karkata with shanta",
    "Get an image which she performing ardhachandra on left hand with rudra rasa",
    "Show me a picture which man performing mrigashirsha on left hand and kartari on right hand with hasya rasa",
    "Fetch me a picture of he performing mayura on left hand and suchi on right hand with rudra rasa",
    "Get me where female performing chakra with veera rasa",
    "Retrieve an instance of boy performing swastika with bhaya rasa",
    "Retrieve an image which woman performing mrigashirsha on left hand and mukula on right hand with bhaya rasa",
]
for txt in q_list:
    doc=nlp(txt)
    displacy.render(nlp(doc.text),style='ent',jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Retrieve an instance which
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     boy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GENDER</span>
# </mark>
#
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     performing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nagabandha
# ...
